# %%
## Importing the files
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import 
import datetime as dt

# %%
## Read the file
file = pd.ExcelFile(r'C:\Users\venkatesh\interview\Interview_CaseStudy2.xlsx')

# %%
file.sheet_names## read the sheet names
# Out:
# ['Question',
#  'Transaction Data',
#  'Product Data',
#  'Store Data',
#  'Segmentation Data',
#  'Data Dictionary']

# %%
df1 = pd.read_excel(file, 'Transaction Data')
df2 = pd.read_excel(file, 'Product Data')
df3 = pd.read_excel(file, 'Store Data')

# %%
df1.shape,df2.shape,df3.shape
# Out:
# ((131640, 13), (2019, 8), (21, 3))

# %%
## Lets merge the data with the unique ids
trans_product=pd.merge(df1, df2, on='UPC_ID',how='left')

# %%
trans_product
# Out:
#                      TXN_ID                  BSK     TXN_DT  \
# 0       6825100070076291408  6825100070076290048 2018-09-08
# 1       6952100110107401416  6952100110107400192 2019-09-16
# 2       6952100110104505595  6952100110104500224 2019-09-01
# 3       6818100060078387658  6818100060078380032 2018-09-01
# 4       6952100110104928796  6952100110104920064 2019-09-08
# ...                     ...                  ...        ...
# 131635  6826100100072156635  6826100100072150016 2018-09-09
# 131636  6846100110065364840  6846100110065359872 2018-09-29
# 131637  6952100110107777306  6952100110107769856 2019-09-28
# 131638  6843100100073859186  6843100100073849856 2018-09-26
# 131639  6952100110107554515  6952100110107549696 2019-09-27
#
#                HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  ITEM_QTY  MKDN_AMT  \
# 0               18070030804        21  112200381     0.99         1         0
# 1               18239954704         7  112101684     5.99         1         0
# ...

# %%
trans_product.isnull().sum()
# Out:
# TXN_ID               0
# BSK                  0
# TXN_DT               0
# HOUSEHOLD_ID         0
# STORE_ID             0
# UPC_ID               0
# NET_AMT              0
# ITEM_QTY             0
# MKDN_AMT             0
# FACTS_2019           0
# FACTS_2018           0
# TRUPRICE_2019        0
# TRUPRICE_2018        0
# UPC_DESC             0
# L4 ID                0
# L4_DESC              0
# L5_ID                0
# L5_DESC              0
# MANUFACTURER_NAME    0
# BRAND_NAME           0
# dtype: int64

# %%
## Merging the above file with store ID
df=pd.merge(trans_product,df3,on='STORE_ID',how='left')

# %%
df.shape
# Out:
# (131640, 22)

# %%
df.columns
# Out:
# Index(['TXN_ID', 'BSK', 'TXN_DT', 'HOUSEHOLD_ID', 'STORE_ID', 'UPC_ID',
#        'NET_AMT', 'ITEM_QTY', 'MKDN_AMT', 'FACTS_2019', 'FACTS_2018',
#        'TRUPRICE_2019', 'TRUPRICE_2018', 'UPC_DESC', 'L4 ID', 'L4_DESC',
#        'L5_ID', 'L5_DESC', 'MANUFACTURER_NAME', 'BRAND_NAME', 'STORE_NM',
#        'REGION_NM'],
#       dtype='object')

# %%
df
# Out:
#                      TXN_ID                  BSK     TXN_DT  \
# 0       6825100070076291408  6825100070076290048 2018-09-08
# 1       6952100110107401416  6952100110107400192 2019-09-16
# 2       6952100110104505595  6952100110104500224 2019-09-01
# 3       6818100060078387658  6818100060078380032 2018-09-01
# 4       6952100110104928796  6952100110104920064 2019-09-08
# ...                     ...                  ...        ...
# 131635  6826100100072156635  6826100100072150016 2018-09-09
# 131636  6846100110065364840  6846100110065359872 2018-09-29
# 131637  6952100110107777306  6952100110107769856 2019-09-28
# 131638  6843100100073859186  6843100100073849856 2018-09-26
# 131639  6952100110107554515  6952100110107549696 2019-09-27
#
#                HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  ITEM_QTY  MKDN_AMT  \
# 0               18070030804        21  112200381     0.99         1         0
# 1               18239954704         7  112101684     5.99         1         0
# ...

# %%
df.columns
# Out:
# Index(['TXN_ID', 'BSK', 'TXN_DT', 'HOUSEHOLD_ID', 'STORE_ID', 'UPC_ID',
#        'NET_AMT', 'ITEM_QTY', 'MKDN_AMT', 'FACTS_2019', 'FACTS_2018',
#        'TRUPRICE_2019', 'TRUPRICE_2018', 'UPC_DESC', 'L4 ID', 'L4_DESC',
#        'L5_ID', 'L5_DESC', 'MANUFACTURER_NAME', 'BRAND_NAME', 'STORE_NM',
#        'REGION_NM'],
#       dtype='object')

# %%
drop_col=['TXN_ID','BSK']

# %%
df=df.drop(drop_col,axis=1)

# %%
df
# Out:
#            TXN_DT         HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  \
# 0      2018-09-08          18070030804        21  112200381     0.99
# 1      2019-09-16          18239954704         7  112101684     5.99
# 2      2019-09-01 -6952100110104505595        29  112300268     3.64
# 3      2018-09-01          15060009104        15  112500042     9.98
# 4      2019-09-08           4166509704         4  112200697     1.40
# ...           ...                  ...       ...        ...      ...
# 131635 2018-09-09           3078142504         3  111200623     2.19
# 131636 2018-09-29           7225909004         7  112101069     0.99
# 131637 2019-09-28         421000338021        25  112500074     2.24
# 131638 2018-09-26          18285010104        18  111200673     1.09
# 131639 2019-09-27           9239230104         9  112000070     1.10
#
#         ITEM_QTY  MKDN_AMT  FACTS_2019  FACTS_2018  TRUPRICE_2019  \
# 0              1         0          -9           1              2
# ...

# %%
## Lets split the data with month to analysis
df.loc[:,'year']=df['TXN_DT'].dt.year
df.loc[:,'date']=df['TXN_DT'].dt.day

# %%
df
# Out:
#            TXN_DT         HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  \
# 0      2018-09-08          18070030804        21  112200381     0.99
# 1      2019-09-16          18239954704         7  112101684     5.99
# 2      2019-09-01 -6952100110104505595        29  112300268     3.64
# 3      2018-09-01          15060009104        15  112500042     9.98
# 4      2019-09-08           4166509704         4  112200697     1.40
# ...           ...                  ...       ...        ...      ...
# 131635 2018-09-09           3078142504         3  111200623     2.19
# 131636 2018-09-29           7225909004         7  112101069     0.99
# 131637 2019-09-28         421000338021        25  112500074     2.24
# 131638 2018-09-26          18285010104        18  111200673     1.09
# 131639 2019-09-27           9239230104         9  112000070     1.10
#
#         ITEM_QTY  MKDN_AMT  FACTS_2019  FACTS_2018  TRUPRICE_2019  ...  L4 ID  \
# ...

# %%
df
# Out:
#            TXN_DT         HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  \
# 0      2018-09-08          18070030804        21  112200381     0.99
# 1      2019-09-16          18239954704         7  112101684     5.99
# 2      2019-09-01 -6952100110104505595        29  112300268     3.64
# 3      2018-09-01          15060009104        15  112500042     9.98
# 4      2019-09-08           4166509704         4  112200697     1.40
# ...           ...                  ...       ...        ...      ...
# 131635 2018-09-09           3078142504         3  111200623     2.19
# 131636 2018-09-29           7225909004         7  112101069     0.99
# 131637 2019-09-28         421000338021        25  112500074     2.24
# 131638 2018-09-26          18285010104        18  111200673     1.09
# 131639 2019-09-27           9239230104         9  112000070     1.10
#
#         ITEM_QTY  MKDN_AMT  FACTS_2019  FACTS_2018  TRUPRICE_2019  ...  L4 ID  \
# ...

# %%
##submission=df

# %%
##submission.to_csv(r"C:\Users\venkatesh\intwerview_in.csv",index="True")

# %%
plt.figure(figsize=(10,5))
sns.barplot(df.date,df.NET_AMT)

# %%
## lets split the data by year
df_2018=df[df.year==2018]
df_2019=df[df.year==2019]

# %%
df_2018
# Out:
#            TXN_DT         HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  \
# 0      2018-09-08          18070030804        21  112200381     0.99
# 3      2018-09-01          15060009104        15  112500042     9.98
# 5      2018-09-23           6280729604         6  112200834     3.89
# 6      2018-09-23          10150293304        10  112000126     4.59
# 7      2018-09-23 -6840100070078100908        29  112101151     2.29
# ...           ...                  ...       ...        ...      ...
# 131629 2018-09-19           9310211304         9  112200639     4.99
# 131631 2018-09-02         400007780682        32  112300594     2.52
# 131635 2018-09-09           3078142504         3  111200623     2.19
# 131636 2018-09-29           7225909004         7  112101069     0.99
# 131638 2018-09-26          18285010104        18  111200673     1.09
#
#         ITEM_QTY  MKDN_AMT  FACTS_2019  FACTS_2018  TRUPRICE_2019  ...  L4 ID  \
# ...

# %% [markdown]
# ## coorelation  of  2018 and 2019 vs sales and discounts

# %%
corr_2018=df_2018[["NET_AMT","ITEM_QTY","MKDN_AMT","date"]]
corr_2019=df_2019[["NET_AMT","ITEM_QTY","MKDN_AMT","date"]]
fig,ax=plt.subplots(1,2,figsize=(15,5))
sns.heatmap(corr_2018.corr(),annot=True,ax=ax[0])
sns.heatmap(corr_2019.corr(),annot=True,ax=ax[1])
plt.show()

# %%
## 2018
## observation: as days increases the sales are decreasing
## observation : as date increase the discount has not increasing it close to zero

# %%
## 2019
## observation: date increase sales decrease and date inrease discount not increase its close to zero
## compare to 2018 the sales has increase when discount increase

# %% [markdown]
# ## Date VS Net sales  and Date vs discount

# %%
fig, ax =plt.subplots(1,2,figsize=(17,5))
sns.lineplot(df_2018.date,df_2018.NET_AMT,ax=ax[0],estimator='sum' ,marker='o')
sns.lineplot(df_2019.date,df_2019.NET_AMT,ax=ax[0],estimator='sum', marker='o')
sns.lineplot(df_2018.date,df_2018.MKDN_AMT,ax=ax[1],estimator='sum',marker='o')
sns.lineplot(df_2019.date,df_2019.MKDN_AMT,ax=ax[1],estimator='sum',marker='o')
plt.show()

# %%
## observation: the Net sales of 2018 started on high but its decreasing once its moving to end of the month
## for 2019 its low when compare to 2019 and its end on high comparing to 2018 sales

# %%
## observation: comapre to 2018, in 2019 we have provided more discounts at the end of the month 

## does the sales in end of the month of 2019 increased considering the discount provided at the end of the month?
## IS there a significant impact on sales considering the discounts at the end of the month?

# %% [markdown]
# ## Store Name vs sales

# %%
plt.figure(figsize=(15,5))
sns.lineplot(df_2018.STORE_NM,df_2018.NET_AMT,estimator='sum',marker='o')
sns.lineplot(df_2019.STORE_NM,df_2019.NET_AMT,estimator='sum',marker='o')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## store name vs discount

# %%
plt.figure(figsize=(15,5))
sns.lineplot(df_2018.STORE_NM,df_2018.MKDN_AMT,estimator='sum' ,marker='o')
sns.lineplot(df_2019.STORE_NM,df_2019.MKDN_AMT,estimator='sum' ,marker='o')
plt.xticks(rotation=45)
plt.show()

# %%
## Despite of high discount in 2019 the sales are not impacted. 2018 sales are still high then 2019 
## Rozzano,Rubicone,senate and varesa have provied significantly high discount comapre to rest of the stores
##despite of high discount in serite in 2019 the sales is less comapre to 2018. 
##

# %% [markdown]
# ## Store iD vs sales

# %%
ax=plt.figure(figsize=(15,5))
sns.lineplot(df_2018.STORE_ID,df_2018.NET_AMT,estimator='sum' ,marker='o')
sns.lineplot(df_2019.STORE_ID,df_2019.NET_AMT,estimator='sum' ,marker='o')
plt.show()

# %% [markdown]
# ## store id vs discount

# %%
ax=plt.figure(figsize=(15,5))
sns.lineplot(df_2018.STORE_ID,df_2018.MKDN_AMT,estimator='sum' ,marker='o')
sns.lineplot(df_2019.STORE_ID,df_2019.MKDN_AMT,estimator='sum' ,marker='o')
plt.show()

# %%
## observation: similar to storename ids 6,7,8 and 9 has significantly provided higher discounts
##

# %%
fig, ax =plt.subplots(1,2,figsize=(17,5))
sns.lineplot(df_2018.REGION_NM,df_2018.NET_AMT,ax=ax[0],estimator='sum' ,marker='o')
sns.lineplot(df_2019.REGION_NM,df_2019.NET_AMT,ax=ax[0],estimator='sum' ,marker='o')
sns.lineplot(df_2018.REGION_NM,df_2018.MKDN_AMT,ax=ax[1],estimator='sum' ,marker='o')
sns.lineplot(df_2019.REGION_NM,df_2019.MKDN_AMT,ax=ax[1],estimator='sum' ,marker='o')

##plt.title("Region_name vs Net amout")
plt.show()
print("region for 2018\n",df_2018.REGION_NM.value_counts())
print("region for 2019\n",df_2019.REGION_NM.value_counts())
# Out:
# region for 2018
#  Lombardia         54809
# Veneto             5363
# Piemonte           5190
# Emilia Romagna     4560
# Name: REGION_NM, dtype: int64
# region for 2019
#  Lombardia         47577
# Piemonte           5117
# Veneto             4657
# Emilia Romagna     4367
# Name: REGION_NM, dtype: int64

# %%
## observation:
## As we observed with storename and id. 
## Since Most of the transaction is in the Lombardia region. its obvious to have higher sales
## Three stores in Lombardia region performs well along with Rubicone in emilia Romagna

# %% [markdown]
# ## Differene in sales on each date bw 2018 and 2019

# %%
grp=df_2018.groupby('date')
date_sales_percent_2018=(grp.NET_AMT.sum())
##date_sales_percent_2018=round(date_sales_percent_2018,2)

# %%
grp2=df_2019.groupby('date')
date_sales_percent_2019=(grp2.NET_AMT.sum())
##date_sales_percent_2019=round(date_sales_percent_2019,2)

# %%
grp3=df_2018.groupby('date')['MKDN_AMT'].sum()
grp4=df_2019.groupby('date')['MKDN_AMT'].sum()

# %%
difference_discount=grp3-grp4

# %%
difference_discount
# Out:
# date
# 1      718
# 2      417
# 3      434
# 4      285
# 5      177
# 6      114
# 7       56
# 8      506
# 9        7
# 10     167
# 11     -15
# 12      79
# 13      65
# 14    -623
# 15     343
# 16     531
# 17      22
# 18     125
# 19      93
# 20      34
# 21     547
# 22     983
# 23   -1174
# 24    -936
# 25   -1208
# 26   -1160
# 27   -1109
# 28   -2217
# 29    -842
# 30    -451
# Name: MKDN_AMT, dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.plot(difference_discount,marker='o',color='red')
plt.xlabel("Days")
plt.title("Difference in discount on date wise in 2018 and 2019")
plt.xticks(np.arange(1,31,1))
plt.show()

# %%
total_diff=(date_sales_percent_2018 - date_sales_percent_2019)

# %%
total_diff_percent= total_diff/total_diff.sum()

# %%
total_diff_percent=round(total_diff_percent,2)

# %%
plt.figure(figsize=(15,5))
plt.plot(total_diff,marker='o',color='red')
plt.xlabel("Days")
plt.title("Difference in Sales on date wise in 2018 and 2019")
plt.xticks(np.arange(1,31,1))
plt.show()

# %%
## observation: we can see the increase in sales in every weekends on 2019  ie saturday 1,7,14,21,28
## observation : similarly we can see the increase in sale in weekens on 2018 ie saturday 8,15,22,29

# %%
lst1=[7,14,21,28]
lst2=[8,15,22,29]

# %%
##for i in lst2:
date_weekend=df_2018[df_2018.date.isin(lst2)]

# %% [markdown]
# ## Week end sales in 2018

# %%
ax=round(date_weekend.groupby('date')["NET_AMT"].sum(),2).plot(kind='bar',color='magenta')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.01, p.get_height()))
plt.title("Weekend sales in 2018")
plt.show()

# %%
sum_weekend_2018=date_weekend.groupby('date')["NET_AMT"].sum()

# %%
sum_weekend_2018.sum()
# Out:
# 42828.21999999946

# %%
sum_weekend_2019=date_weekend_2019.groupby('date')["NET_AMT"].sum()

# %%
sum_weekend_2019.sum()
# Out:
# 39541.699999999546

# %% [markdown]
# ## Weekend sales in 2019

# %%
ax=round(date_weekend_2019.groupby('date')["NET_AMT"].sum(),2).plot(kind='bar',color='magenta')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.01, p.get_height()))
plt.title("Weekend sales in 2019")
plt.show()

# %%
date_weekend_2019=df_2019[df_2019.date.isin(lst1)]

# %%
date_weekend_2019.groupby('date')["NET_AMT"].sum()
# Out:
# date
# 7     11102.53
# 14     9616.99
# 21     8548.10
# 28    10274.08
# Name: NET_AMT, dtype: float64

# %% [markdown]
# ## Week end discounts in 2018

# %%
ax=round(date_weekend.groupby('date')["MKDN_AMT"].sum(),2).plot(kind='bar',color='purple')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.1, p.get_height()))
plt.title("Weekend discounts in 2018")
plt.show()

# %%
ax=round(date_weekend_2019.groupby('date')["MKDN_AMT"].sum(),2).plot(kind='bar',color='purple')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.1, p.get_height()))
plt.title("Weekend discounts in 2019")
plt.show()

# %%
sum_2019_weekend_dis=date_weekend_2019.groupby('date')["MKDN_AMT"].sum()
sum_2019_weekend_dis.sum()
# Out:
# 6136

# %%
sum_2018_weekend_dis=date_weekend.groupby('date')["MKDN_AMT"].sum()
sum_2018_weekend_dis.sum()
# Out:
# 5719

# %% [markdown]
# ## Discount

# %%
total_2018_discount=df_2018.MKDN_AMT.sum()

# %%
ax=df.groupby('year')['MKDN_AMT'].sum().plot(kind='bar',color='orange')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.158, p.get_height()))
plt.title("Overall discounts vs year")
plt.show()

# %%
total_2019_discount=df_2019.MKDN_AMT.sum()

# %%
total_dff_discount=(total_2019_discount - total_2018_discount)

# %%
total_dff_discount
# Out:
# 4032

# %%
total_2018_discount/total_2019_discount
# Out:
# 0.8824215560480578

# %%
overall_increase=(total_dff_discount/total_2019_discount)

# %%
overall_increase
# Out:
# 0.11757844395194214

# %% [markdown]
# ## observation : 11.75%  of discount have addiotionally provided in 2019 compare to 2018

# %% [markdown]
# ## Over all sales and avg sales

# %%
df_2018.NET_AMT.sum(),df_2019.NET_AMT.sum()
# Out:
# (239422.7, 212307.98)

# %%
plt.figure(figsize=(10,5))
ax=round(df.groupby('year')['NET_AMT'].sum(),2).plot(kind='bar',width=0.3,color='blue')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.08, p.get_height()))
plt.title("overall sales vs year")
plt.show()

# %%
df_2018.NET_AMT.sum(),df_2019.NET_AMT.sum()
# Out:
# (239422.7, 212307.98)

# %%
df_2018.NET_AMT.mean(),df_2019.NET_AMT.mean()
# Out:
# (3.4241397557276216, 3.439968566706538)

# %%
## over all transaction in 2018 and 2019 vs sales

# %% [markdown]
# ## observation: average sale is almost similar bw 2018 and 2019

# %% [markdown]
# ## general proportion of the data bw 2018 and 2019

# %%
df_2018.shape,df_2019.shape
# Out:
# ((69922, 22), (61718, 22))

# %%
plt.figure(figsize=(10,5))
ax=df.year.value_counts().plot(kind='bar',width=0.3)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.1, p.get_height()))
plt.title("No of transactions vs year")
plt.show()

# %%
sns.countplot(df_2018.date,order=df_2018.date.value_counts().index)

# %% [markdown]
# ## observation: The average sales says both 2018 and 2019 sales are similar

# %% [markdown]
# ## duplicated rows

# %%
dupli_2018=df_2018[df_2018.duplicated()]

# %%
dupli_2018
# Out:
#            TXN_DT  HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  ITEM_QTY  \
# 58754  2018-09-26  400012495984         4  111351589     7.42         1
# 80131  2018-09-05    8242962604         8  112000152     0.85         1
# 83614  2018-09-04   10085804604        10  112101648     8.90         1
# 87133  2018-09-21   20026924304         5  112000071     0.65         1
# 106917 2018-09-04   11027178404        25  111300960     1.45         1
# 116565 2018-09-05    8242962604         8  112200388     3.39         1
# 118918 2018-09-26    4175398304         4  112200537     3.49         1
# 119902 2018-09-07    8061144904         8  112000155     2.99         1
# 120020 2018-09-26   15069562104        15  112000144     1.79         1
# 125306 2018-09-05    8242962604         8  111100258     4.29         1
#
#         MKDN_AMT  FACTS_2019  FACTS_2018  TRUPRICE_2019  ...  L4 ID  \
# 58754          0           3           2             -9  ...    125
# ...

# %%
dupli_2019=df_2019[df_2019.duplicated()]

# %%
dupli_2019
# Out:
#            TXN_DT   HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  ITEM_QTY  \
# 33153  2019-09-05  8199000173676         9  112500016     5.90         1
# 42571  2019-09-27    10013210304        10  111200476     1.10         2
# 47634  2019-09-04     7065342704         7  112200905     1.59         1
# 73735  2019-09-05  8199000173676         9  112101434     2.49         1
# 112879 2019-09-01    10165958304        10  112500029     3.25         1
# 116746 2019-09-11   400007506190         8  112101729     1.99         1
# 130016 2019-09-22   400012151613         9  111371065     1.49         1
#
#         MKDN_AMT  FACTS_2019  FACTS_2018  TRUPRICE_2019  ...  L4 ID  \
# 33153          0           3           3              3  ...    125
# 42571          0           1           1              1  ...    122
# 47634          0           1           2              3  ...    122
# 73735          0           3           3              3  ...    121
# ...

# %%
## There are few duplicated rows in both 2018 and 2019 but there is no significant amount of rows. hence we can keep as it is

# %%
df_2018
# Out:
#            TXN_DT         HOUSEHOLD_ID  STORE_ID     UPC_ID  NET_AMT  \
# 0      2018-09-08          18070030804        21  112200381     0.99
# 3      2018-09-01          15060009104        15  112500042     9.98
# 5      2018-09-23           6280729604         6  112200834     3.89
# 6      2018-09-23          10150293304        10  112000126     4.59
# 7      2018-09-23 -6840100070078100908        29  112101151     2.29
# ...           ...                  ...       ...        ...      ...
# 131629 2018-09-19           9310211304         9  112200639     4.99
# 131631 2018-09-02         400007780682        32  112300594     2.52
# 131635 2018-09-09           3078142504         3  111200623     2.19
# 131636 2018-09-29           7225909004         7  112101069     0.99
# 131638 2018-09-26          18285010104        18  111200673     1.09
#
#         ITEM_QTY  MKDN_AMT  FACTS_2019  FACTS_2018  TRUPRICE_2019  ...  L4 ID  \
# ...

# %%
df_2018.columns
# Out:
# Index(['TXN_DT', 'HOUSEHOLD_ID', 'STORE_ID', 'UPC_ID', 'NET_AMT', 'ITEM_QTY',
#        'MKDN_AMT', 'FACTS_2019', 'FACTS_2018', 'TRUPRICE_2019',
#        'TRUPRICE_2018', 'UPC_DESC', 'L4 ID', 'L4_DESC', 'L5_ID', 'L5_DESC',
#        'MANUFACTURER_NAME', 'BRAND_NAME', 'STORE_NM', 'REGION_NM', 'year',
#        'date'],
#       dtype='object')

# %% [markdown]
# ## Facts 2018 vs 2019

# %%
df_2018.loc[(df_2018.FACTS_2018==1) & (df_2018.FACTS_2019==1), 'compare_facts']= 'elite_elite'
df_2018.loc[(df_2018.FACTS_2018==1) & (df_2018.FACTS_2019==2), 'compare_facts']= 'elite_good'
df_2018.loc[(df_2018.FACTS_2018==1) & (df_2018.FACTS_2019==3), 'compare_facts']= 'elite_occ'
df_2018.loc[(df_2018.FACTS_2018==1) & (df_2018.FACTS_2019==-9), 'compare_facts']= 'elite_unn'

df_2018.loc[(df_2018.FACTS_2018==2) & (df_2018.FACTS_2019==2), 'compare_facts']= 'good_good'
df_2018.loc[(df_2018.FACTS_2018==2) & (df_2018.FACTS_2019==1), 'compare_facts']= 'good_elite'
df_2018.loc[(df_2018.FACTS_2018==2) & (df_2018.FACTS_2019==3), 'compare_facts']= 'good_occ'
df_2018.loc[(df_2018.FACTS_2018==2) & (df_2018.FACTS_2019==-9), 'compare_facts']= 'good_unn'

df_2018.loc[(df_2018.FACTS_2018==3) & (df_2018.FACTS_2019==3), 'compare_facts']= 'occ_occ'
df_2018.loc[(df_2018.FACTS_2018==3) & (df_2018.FACTS_2019==1), 'compare_facts']= 'occ_elite'
df_2018.loc[(df_2018.FACTS_2018==3) & (df_2018.FACTS_2019==2), 'compare_facts']= 'occ_good'
df_2018.loc[(df_2018.FACTS_2018==3) & (df_2018.FACTS_2019==-9), 'compare_facts']= 'occ_unn'

df_2018.loc[(df_2018.FACTS_2018==-9) & (df_2018.FACTS_2019==-9), 'compare_facts']= 'unn_unn'
df_2018.loc[(df_2018.FACTS_2018==-9) & (df_2018.FACTS_2019==1), 'compare_facts']= 'unn_elite'
df_2018.loc[(df_2018.FACTS_2018==-9) & (df_2018.FACTS_2019==2), 'compare_facts']= 'unn_good'
df_2018.loc[(df_2018.FACTS_2018==-9) & (df_2018.FACTS_2019==3), 'compare_facts']= 'unn_occ'
# Out:
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(df_2018.compare_facts,order = df_2018['compare_facts'].value_counts().index)
plt.xticks(rotation=45)
plt.title("Facts2018 to Facts2019")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.03, i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')

# %%
df_per_compare=round(df_2018.compare_facts.value_counts()/df_2018.compare_facts.value_counts().sum(),4)*100

# %%
df_per_compare
# Out:
# elite_elite    21.64
# good_good      16.86
# unn_unn        12.48
# elite_good      9.22
# good_occ        8.35
# occ_occ         7.59
# occ_unn         5.82
# good_unn        5.58
# good_elite      5.28
# occ_good        3.39
# elite_occ       1.99
# elite_unn       1.58
# occ_elite       0.23
# Name: compare_facts, dtype: float64

# %%
## observation: customer with same engagement 58.57%
## customer engagement degraded percentage  32.54%
## customer who have updraged with engagement is around 9%

# %% [markdown]
# ## observation: are we loosing the customer engagement?

# %%
comparefacts_with_discount=df_2018.groupby('compare_facts')['MKDN_AMT'].sum()

# %%
plt.figure(figsize=(15,5))
ax=comparefacts_with_discount.sort_values(ascending=False).plot(kind='bar',color='dimgrey')
plt.xticks(rotation=45)
plt.ylabel("Discounts")
plt.title("Facts2018_2019 vs discounts 2018")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.03, i.get_height()+.99, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=13,
                color='forestgreen')
plt.show()

# %%
comparefacts_with_discount_per=round(comparefacts_with_discount/df_2018.MKDN_AMT.sum(),4)*100

# %%
comparefacts_with_discount_per
# Out:
# compare_facts
# elite_elite    18.70
# elite_good      8.40
# elite_occ       1.99
# elite_unn       1.47
# good_elite      5.24
# good_good      17.57
# good_occ        9.99
# good_unn        6.56
# occ_elite       0.21
# occ_good        4.19
# occ_occ        11.40
# occ_unn        10.20
# unn_unn         4.07
# Name: MKDN_AMT, dtype: float64

# %%
## observation: elite in 2019 from good,occ,unn  in 2018 only provided ≈5.3% percent discount on overall 2019 sep
## observation: customers who have engagement in the same way we have provided  ≈52% discount
## observation: good in 2019 from occ,unn in 2018 has ≈4.1% discounts
## observation: customers who have degraded ie elite-good 8.4,occ 1.99,unn 1.47  ,occ-unn 10.2% ,good - occ 9.9 ,unn 6.5%, occ - unn - 10% ie overall ≈38.6%

# %%
## are we missing the customer who are converting to good and elite customers?

# %%
comparefacts_with_sales=df_2018.groupby('compare_facts')['NET_AMT'].sum()

# %%
comparefacts_with_sales_per_2018=round(comparefacts_with_sales/df_2018.NET_AMT.sum(),2)*100

# %%
plt.figure(figsize=(15,5))
ax=comparefacts_with_sales.sort_values(ascending=False).plot(kind='bar',color='dimgrey')
plt.xticks(rotation=45)
plt.ylabel("sales")
plt.title("Facts2018_2019 vs sales 2018")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.03, i.get_height()+0.01, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=13,
                color='forestgreen')
plt.show()

# %%
## observation:
## customers with same engagement has  approx 58% sales
## customers who are degraded  approx 33.08%
## customers who are upgraded  has 8.33% sales

# %%
comparefacts_with_sales_per_2018.sort_values(ascending=False)
# Out:
# compare_facts
# elite_elite    19.0
# good_good      16.0
# unn_unn        14.0
# good_occ        9.0
# occ_occ         9.0
# elite_good      8.0
# occ_unn         7.0
# good_unn        6.0
# good_elite      5.0
# occ_good        4.0
# elite_occ       2.0
# elite_unn       1.0
# occ_elite       0.0
# Name: NET_AMT, dtype: float64

# %% [markdown]
# ## Facts 2019 and 2018

# %%
df_2019.loc[(df_2019.FACTS_2019==1) & (df_2019.FACTS_2018==1), 'compare_facts']= 'elite_elite'
df_2019.loc[(df_2019.FACTS_2019==1) & (df_2019.FACTS_2018==2), 'compare_facts']= 'elite_good'
df_2019.loc[(df_2019.FACTS_2019==1) & (df_2019.FACTS_2018==3), 'compare_facts']= 'elite_occ'
df_2019.loc[(df_2019.FACTS_2019==1) & (df_2019.FACTS_2018==-9), 'compare_facts']= 'elite_unn'

df_2019.loc[(df_2019.FACTS_2019==2) & (df_2019.FACTS_2018==2), 'compare_facts']= 'good_good'
df_2019.loc[(df_2019.FACTS_2019==2) & (df_2019.FACTS_2018==1), 'compare_facts']= 'good_elite'
df_2019.loc[(df_2019.FACTS_2019==2) & (df_2019.FACTS_2018==3), 'compare_facts']= 'good_occ'
df_2019.loc[(df_2019.FACTS_2019==2) & (df_2019.FACTS_2018==-9), 'compare_facts']= 'good_unn'

df_2019.loc[(df_2019.FACTS_2019==3) & (df_2019.FACTS_2018==3), 'compare_facts']= 'occ_occ'
df_2019.loc[(df_2019.FACTS_2019==3) & (df_2019.FACTS_2018==1), 'compare_facts']= 'occ_elite'
df_2019.loc[(df_2019.FACTS_2019==3) & (df_2019.FACTS_2018==2), 'compare_facts']= 'occ_good'
df_2019.loc[(df_2019.FACTS_2019==3) & (df_2019.FACTS_2018==-9), 'compare_facts']= 'occ_unn'

df_2019.loc[(df_2019.FACTS_2019==-9) & (df_2019.FACTS_2018==-9), 'compare_facts']= 'unn_unn'
df_2019.loc[(df_2019.FACTS_2019==-9) & (df_2019.FACTS_2018==1), 'compare_facts']= 'unn_elite'
df_2019.loc[(df_2019.FACTS_2019==-9) & (df_2019.FACTS_2018==2), 'compare_facts']= 'unn_good'
df_2019.loc[(df_2019.FACTS_2019==-9) & (df_2019.FACTS_2018==3), 'compare_facts']= 'unn_occ'
# Out:
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(df_2019.compare_facts,order = df_2019['compare_facts'].value_counts().index)
plt.xticks(rotation=45)
plt.title("Facts2019 to Facts2018")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.03, i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')

# %%
df_per_compare_2019=round(df_2019.compare_facts.value_counts()/df_2019.compare_facts.value_counts().sum(),4)*100

# %%
df_per_compare_2019
# Out:
# elite_elite    22.39
# good_good      17.37
# unn_unn        12.88
# elite_good      7.85
# occ_occ         7.71
# good_occ        7.31
# good_elite      6.33
# good_unn        5.90
# occ_unn         5.32
# occ_good        3.43
# elite_unn       1.76
# elite_occ       1.46
# occ_elite       0.28
# Name: compare_facts, dtype: float64

# %%
## observation: customer with same engagement approx 60.35%
## customer engagement updraded percentage approx 29.6%
## customer who have degraded with engagement is around approx 10.4%

# %%
## do we missed the upgraded customer

# %%
comparefacts_with_discount_2019=df_2019.groupby('compare_facts')['MKDN_AMT'].sum()

# %%
plt.figure(figsize=(15,5))
ax=comparefacts_with_discount_2019.sort_values(ascending=False).plot(kind='bar',color='dimgrey')
plt.xticks(rotation=45)
plt.ylabel("Discounts")
plt.title("Facts2019_2018 vs discounts 2019")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.001, i.get_height()+.99, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=13,
                color='forestgreen')

plt.show()

# %%
comparefacts_with_discount_per_2019=round(comparefacts_with_discount_2019/df_2019.MKDN_AMT.sum(),4)*100

# %%
comparefacts_with_discount_per_2019
# Out:
# compare_facts
# elite_elite    17.49
# elite_good      7.29
# elite_occ       1.74
# elite_unn       1.35
# good_elite      6.34
# good_good      17.49
# good_occ       11.16
# good_unn        6.61
# occ_elite       0.32
# occ_good        5.02
# occ_occ        12.58
# occ_unn        10.06
# unn_unn         2.55
# Name: MKDN_AMT, dtype: float64

# %%
## observation: elite in 2019 from good,occ,unn  in 2018 only provided 10% percent discount on overall 2019 sep overall 38.21
## observation: customers who have engagement in the same way we have provided  50% discount
## observation: good in 2019 to occ,unn in 2018 has 18%
## observation: occ in 2019 to unn in 2018 has 10 %
## observation: customers who have degraded have 11.7%

# %% [markdown]
# ## Have we missed to provide the discounts to degraded customers??

# %%
comparefacts_with_sales_2019=df_2019.groupby('compare_facts')['NET_AMT'].sum()

# %%
plt.figure(figsize=(15,5))
ax=comparefacts_with_sales_2019.sort_values(ascending=False).plot(kind='bar',color='dimgrey')
plt.xticks(rotation=45)
plt.ylabel("Discounts")
plt.title("Facts2019_2018 vs sales 2019")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.001, i.get_height()+.99, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=13,
                color='forestgreen')

plt.show()

# %%
## same engegement - 59.52%
##  upgraded    - 30.36%
## degraded -  10.11%

# %%
comparefacts_with_sales_per_2019=round(comparefacts_with_sales_2019/df_2019.NET_AMT.sum(),2)*100

# %%
comparefacts_with_sales_per_2019.sort_values(ascending=False)
# Out:
# compare_facts
# elite_elite    19.0
# good_good      17.0
# unn_unn        14.0
# occ_occ        10.0
# good_occ        8.0
# elite_good      7.0
# occ_unn         7.0
# good_elite      6.0
# good_unn        6.0
# occ_good        4.0
# elite_unn       2.0
# elite_occ       1.0
# occ_elite       0.0
# Name: NET_AMT, dtype: float64

# %%
## observation: elite in 2019 from good,occ,unn  in 2018 have approx 10% percent sales on overall 2019 sep
## observation: customers who have engagement in the same way we have 60%  overall sales
## observation: good in 2019 to occ,unn in 2018 has approx14%
## observation: occ in 2019 to unn in 2018 has approx 7 %
## observation: customers who have degraded have approx 10%

# %% [markdown]
# ## Are we cared for upgraded customers?

# %% [markdown]
# ## sensitive to price 2018 and 2019

# %%
df_2018.loc[(df_2018.TRUPRICE_2018==1) & (df_2018.TRUPRICE_2019==1), 'price_seg']= 'mostpricesensitive_mostpricesensitive'
df_2018.loc[(df_2018.TRUPRICE_2018==1) & (df_2018.TRUPRICE_2019==2), 'price_seg']= 'mostpricesensitive_pricesen'
df_2018.loc[(df_2018.TRUPRICE_2018==1) & (df_2018.TRUPRICE_2019==3), 'price_seg']= 'mostpricesensitive_neutral'
df_2018.loc[(df_2018.TRUPRICE_2018==1) & (df_2018.TRUPRICE_2019==4), 'price_seg']= 'mostpricesensitive_quality'
df_2018.loc[(df_2018.TRUPRICE_2018==1) & (df_2018.TRUPRICE_2019==5), 'price_seg']= 'mostpricesensitive_mostquality'
df_2018.loc[(df_2018.TRUPRICE_2018==1) & (df_2018.TRUPRICE_2019==-9), 'price_seg']= 'mostpricesensitive_unn'

df_2018.loc[(df_2018.TRUPRICE_2018==2) & (df_2018.TRUPRICE_2019==2), 'price_seg']= 'pricesen_pricesen'
df_2018.loc[(df_2018.TRUPRICE_2018==2) & (df_2018.TRUPRICE_2019==1), 'price_seg']= 'pricesen_mostpricesensitive'
df_2018.loc[(df_2018.TRUPRICE_2018==2) & (df_2018.TRUPRICE_2019==3), 'price_seg']= 'pricesen_neutral'
df_2018.loc[(df_2018.TRUPRICE_2018==2) & (df_2018.TRUPRICE_2019==4), 'price_seg']= 'pricesen_quality'
df_2018.loc[(df_2018.TRUPRICE_2018==2) & (df_2018.TRUPRICE_2019==5), 'price_seg']= 'pricesen_mostquality'
df_2018.loc[(df_2018.TRUPRICE_2018==2) & (df_2018.TRUPRICE_2019==-9), 'price_seg']= 'pricesen_unn'

df_2018.loc[(df_2018.TRUPRICE_2018==3) & (df_2018.TRUPRICE_2019==3), 'price_seg']= 'neutral_neutral'
df_2018.loc[(df_2018.TRUPRICE_2018==3) & (df_2018.TRUPRICE_2019==1), 'price_seg']= 'neutral_mostpricesensitive'
df_2018.loc[(df_2018.TRUPRICE_2018==3) & (df_2018.TRUPRICE_2019==2), 'price_seg']= 'neutral_pricesen'
df_2018.loc[(df_2018.TRUPRICE_2018==3) & (df_2018.TRUPRICE_2019==4), 'price_seg']= 'neutral_quality'
df_2018.loc[(df_2018.TRUPRICE_2018==3) & (df_2018.TRUPRICE_2019==5), 'price_seg']= 'neutral_mostquality'
df_2018.loc[(df_2018.TRUPRICE_2018==3) & (df_2018.TRUPRICE_2019==-9), 'price_seg']= 'neutral_unn'



df_2018.loc[(df_2018.TRUPRICE_2018==4) & (df_2018.TRUPRICE_2019==4), 'price_seg']= 'quality_quality'
df_2018.loc[(df_2018.TRUPRICE_2018==4) & (df_2018.TRUPRICE_2019==1), 'price_seg']= 'quality_mostpricesensitive'
df_2018.loc[(df_2018.TRUPRICE_2018==4) & (df_2018.TRUPRICE_2019==2), 'price_seg']= 'quality_pricesen'
df_2018.loc[(df_2018.TRUPRICE_2018==4) & (df_2018.TRUPRICE_2019==3), 'price_seg']= 'quality_neutral'
df_2018.loc[(df_2018.TRUPRICE_2018==4) & (df_2018.TRUPRICE_2019==5), 'price_seg']= 'quality_mostquality'
df_2018.loc[(df_2018.TRUPRICE_2018==4) & (df_2018.TRUPRICE_2019==-9), 'price_seg']= 'quality_unn'



df_2018.loc[(df_2018.TRUPRICE_2018==5) & (df_2018.TRUPRICE_2019==5), 'price_seg']= 'mostquality_mostquality'
df_2018.loc[(df_2018.TRUPRICE_2018==5) & (df_2018.TRUPRICE_2019==1), 'price_seg']= 'mostquality_mostpricesensitive'
df_2018.loc[(df_2018.TRUPRICE_2018==5) & (df_2018.TRUPRICE_2019==2), 'price_seg']= 'mostquality_pricesen'
df_2018.loc[(df_2018.TRUPRICE_2018==5) & (df_2018.TRUPRICE_2019==3), 'price_seg']= 'mostquality_neutral'
df_2018.loc[(df_2018.TRUPRICE_2018==5) & (df_2018.TRUPRICE_2019==4), 'price_seg']= 'mostquality_quality'
df_2018.loc[(df_2018.TRUPRICE_2018==5) & (df_2018.TRUPRICE_2019==-9), 'price_seg']= 'mostquality_unn'


df_2018.loc[(df_2018.TRUPRICE_2018==-9) & (df_2018.TRUPRICE_2019==-9), 'price_seg']= 'unn_unn'
df_2018.loc[(df_2018.TRUPRICE_2018==-9) & (df_2018.TRUPRICE_2019==1), 'price_seg']= 'unn_mostpricesensitive'
df_2018.loc[(df_2018.TRUPRICE_2018==-9) & (df_2018.TRUPRICE_2019==2), 'price_seg']= 'unn_pricesen'
df_2018.loc[(df_2018.TRUPRICE_2018==-9) & (df_2018.TRUPRICE_2019==3), 'price_seg']= 'unn_neutral'
df_2018.loc[(df_2018.TRUPRICE_2018==-9) & (df_2018.TRUPRICE_2019==4), 'price_seg']= 'unn_quality'
df_2018.loc[(df_2018.TRUPRICE_2018==-9) & (df_2018.TRUPRICE_2019==5), 'price_seg']= 'unn_mostquality'
# Out:
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(25,5))
ax=sns.countplot(df_2018.price_seg,order = df_2018['price_seg'].value_counts().index)
plt.xticks(rotation=75)
plt.title("price_seg 2018 to price_seg 2019")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.001, i.get_height()+.40, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=13,
                color='forestgreen')

plt.show()

# %%
## Apart from the customers who are price sensitive in 2018 and 2019. rest of the customers are  falling in quality,mostquality and neutral.
## Customers who have changed from quality,neutral to price sensitive is not significant.

##

# %%
price_seg_2018_sales=df_2018.groupby('price_seg')['NET_AMT'].sum()

# %%
price_seg_2018_sales.sum()
# Out:
# 239422.70000000083

# %%
plt.figure(figsize=(25,5))
ax=price_seg_2018_sales.sort_values(ascending=False).plot(kind='bar',color='dimgrey')
plt.xticks(rotation=75)
plt.ylabel("sales")
plt.title("Truprice seg on 2018 vs sales")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.001, i.get_height()+.99, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=10,
                color='forestgreen')

plt.show()

# %% [markdown]
# ## Truprice 2019 and 2018 on 2019

# %%
df_2019.loc[(df_2019.TRUPRICE_2019==1) & (df_2019.TRUPRICE_2018==1), 'price_seg']= 'mostpricesensitive_mostpricesensitive'
df_2019.loc[(df_2019.TRUPRICE_2019==1) & (df_2019.TRUPRICE_2018==2), 'price_seg']= 'mostpricesensitive_pricesen'
df_2019.loc[(df_2019.TRUPRICE_2019==1) & (df_2019.TRUPRICE_2018==3), 'price_seg']= 'mostpricesensitive_neutral'
df_2019.loc[(df_2019.TRUPRICE_2019==1) & (df_2019.TRUPRICE_2018==4), 'price_seg']= 'mostpricesensitive_quality'
df_2019.loc[(df_2019.TRUPRICE_2019==1) & (df_2019.TRUPRICE_2018==5), 'price_seg']= 'mostpricesensitive_mostquality'
df_2019.loc[(df_2019.TRUPRICE_2019==1) & (df_2019.TRUPRICE_2018==-9), 'price_seg']= 'mostpricesensitive_unn'

df_2019.loc[(df_2019.TRUPRICE_2019==2) & (df_2019.TRUPRICE_2018==2), 'price_seg']= 'pricesen_pricesen'
df_2019.loc[(df_2019.TRUPRICE_2019==2) & (df_2019.TRUPRICE_2018==1), 'price_seg']= 'pricesen_mostpricesensitive'
df_2019.loc[(df_2019.TRUPRICE_2019==2) & (df_2019.TRUPRICE_2018==3), 'price_seg']= 'pricesen_neutral'
df_2019.loc[(df_2019.TRUPRICE_2019==2) & (df_2019.TRUPRICE_2018==4), 'price_seg']= 'pricesen_quality'
df_2019.loc[(df_2019.TRUPRICE_2019==2) & (df_2019.TRUPRICE_2018==5), 'price_seg']= 'pricesen_mostquality'
df_2019.loc[(df_2019.TRUPRICE_2019==2) & (df_2019.TRUPRICE_2018==-9), 'price_seg']= 'pricesen_unn'

df_2019.loc[(df_2019.TRUPRICE_2019==3) & (df_2019.TRUPRICE_2018==3), 'price_seg']= 'neutral_neutral'
df_2019.loc[(df_2019.TRUPRICE_2019==3) & (df_2019.TRUPRICE_2018==1), 'price_seg']= 'neutral_mostpricesensitive'
df_2019.loc[(df_2019.TRUPRICE_2019==3) & (df_2019.TRUPRICE_2018==2), 'price_seg']= 'neutral_pricesen'
df_2019.loc[(df_2019.TRUPRICE_2019==3) & (df_2019.TRUPRICE_2018==4), 'price_seg']= 'neutral_quality'
df_2019.loc[(df_2019.TRUPRICE_2019==3) & (df_2019.TRUPRICE_2018==5), 'price_seg']= 'neutral_mostquality'
df_2019.loc[(df_2019.TRUPRICE_2019==3) & (df_2019.TRUPRICE_2018==-9), 'price_seg']= 'neutral_unn'



df_2019.loc[(df_2019.TRUPRICE_2019==4) & (df_2019.TRUPRICE_2018==4), 'price_seg']= 'quality_quality'
df_2019.loc[(df_2019.TRUPRICE_2019==4) & (df_2019.TRUPRICE_2018==1), 'price_seg']= 'quality_mostpricesensitive'
df_2019.loc[(df_2019.TRUPRICE_2019==4) & (df_2019.TRUPRICE_2018==2), 'price_seg']= 'quality_pricesen'
df_2019.loc[(df_2019.TRUPRICE_2019==4) & (df_2019.TRUPRICE_2018==3), 'price_seg']= 'quality_neutral'
df_2019.loc[(df_2019.TRUPRICE_2019==4) & (df_2019.TRUPRICE_2018==5), 'price_seg']= 'quality_mostquality'
df_2019.loc[(df_2019.TRUPRICE_2019==4) & (df_2019.TRUPRICE_2018==-9), 'price_seg']= 'quality_unn'



df_2019.loc[(df_2019.TRUPRICE_2019==5) & (df_2019.TRUPRICE_2018==5), 'price_seg']= 'mostquality_mostquality'
df_2019.loc[(df_2019.TRUPRICE_2019==5) & (df_2019.TRUPRICE_2018==1), 'price_seg']= 'mostquality_mostpricesensitive'
df_2019.loc[(df_2019.TRUPRICE_2019==5) & (df_2019.TRUPRICE_2018==2), 'price_seg']= 'mostquality_pricesen'
df_2019.loc[(df_2019.TRUPRICE_2019==5) & (df_2019.TRUPRICE_2018==3), 'price_seg']= 'mostquality_neutral'
df_2019.loc[(df_2019.TRUPRICE_2019==5) & (df_2019.TRUPRICE_2018==4), 'price_seg']= 'mostquality_quality'
df_2019.loc[(df_2019.TRUPRICE_2019==5) & (df_2019.TRUPRICE_2018==-9), 'price_seg']= 'mostquality_unn'


df_2019.loc[(df_2019.TRUPRICE_2019==-9) & (df_2019.TRUPRICE_2018==-9), 'price_seg']= 'unn_unn'
df_2019.loc[(df_2019.TRUPRICE_2019==-9) & (df_2019.TRUPRICE_2018==1), 'price_seg']= 'unn_mostpricesensitive'
df_2019.loc[(df_2019.TRUPRICE_2019==-9) & (df_2019.TRUPRICE_2018==2), 'price_seg']= 'unn_pricesen'
df_2019.loc[(df_2019.TRUPRICE_2019==-9) & (df_2019.TRUPRICE_2018==3), 'price_seg']= 'unn_neutral'
df_2019.loc[(df_2019.TRUPRICE_2019==-9) & (df_2019.TRUPRICE_2018==4), 'price_seg']= 'unn_quality'
df_2019.loc[(df_2019.TRUPRICE_2019==-9) & (df_2019.TRUPRICE_2018==5), 'price_seg']= 'unn_mostquality'
# Out:
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\venkatesh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(25,5))
ax=sns.countplot(df_2019.price_seg,order = df_2019['price_seg'].value_counts().index)
plt.xticks(rotation=75)
plt.title("price_seg 2019 to price_seg 2018")
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.001, i.get_height()+.99, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=13,
                color='forestgreen')

plt.show()

# %%
# Out:
#   File "<ipython-input-172-bb988fee6a3d>", line 2
#     ax=price_seg_2018_sales.sort_values(ascending=False).plot(kind='bar',color='dimgrey')
#      ^
# SyntaxError: invalid syntax

# %%
##df_per_priceseg_2018=rodfgdfund(df_2018.price_seg.value_counts()/df_2018.price_seg.value_counts().sum(),4)*100

# %%
df_per_priceseg_2018
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-73f80d5d86a2> in <module>
# ----> 1 df_per_priceseg_2018
#
# NameError: name 'df_per_priceseg_2018' is not defined

# %%
## observation:

# %% [markdown]
# ## sales vs brand

# %%
##ax=plt.figure(figsize=(15,5))
##sns.lineplot(df_2018.BRAND_NAME,df_2018.NET_AMT,estimator='sum' ,marker='o',color='red')
##sns.lineplot(df_2019.BRAND_NAME,df_2019.NET_AMT,estimator='sum' ,marker='o',color='green')
##plt.show()

# %%
brnd_2018=df_2018.groupby('BRAND_NAME')['NET_AMT'].sum()

# %%
brnd_2018.sort_values(ascending=False)[:30]
# Out:
# BRAND_NAME
# DASH                    24454.25
# IPER                    17436.25
# FINISH                  11847.39
# DIXAN                   11307.66
# SCOTTEX                 10848.28
# FOXY                     8940.82
# ACE-FATER                7473.75
# SOFFASS REGINA           7342.36
# CHANTECLAIR              6775.84
# OMINO BIANCO             6124.95
# SVELTO                   4755.76
# COCCOLINO                4729.05
# LENOR                    4575.99
# WC NET                   4396.12
# VAPE                     4150.82
# DELICARTA NICKY          3999.92
# PRIL                     3965.72
# CALGON                   3828.16
# SOLE                     3596.57
# GREY ACCHIAPPACOLORE     3497.55
# CUKI                     3442.16
# GLADE                    3333.65
# NAPISAN                  3304.18
# RAID                     2992.81
# VERNEL                   2977.45
# FIOCCO                   2887.57
# BIO PRESTO               2853.68
# VIAKAL                   2777.68
# ...

# %%
date1_2018=df_2018.loc[df_2018['date']==1]

# %%
plt.figure(figsize=(15,5))
top_1_dis=date1_2018.groupby('BRAND_NAME')['MKDN_AMT'].sum()
ax=round(top_1_dis.sort_values(ascending=False)[:20],2).plot(kind='bar',color='magenta')
plt.xticks(rotation=75)
plt.title("SEP 1st,2018 top brand vs discount")
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.09, p.get_height()))
plt.show()

# %%
top_1_dis.sum()
# Out:
# 1844

# %%
top_1_sal.sum()
# Out:
# 18347.710000000003

# %%
top_1_sal_2019.sum()
# Out:
# 11718.240000000002

# %%
plt.figure(figsize=(21,5))
top_1_sal=date1_2018.groupby('BRAND_NAME')['NET_AMT'].sum()
ax=round(top_1_sal.sort_values(ascending=False)[:20],2).plot(kind='bar')
plt.xticks(rotation=75)
plt.title("SEP 1st,2018 TOp brand vs sales")
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.002, p.get_height()))
plt.show()

# %%
date1_2019=df_2019.loc[df_2019['date']==1]
top_1_sal_2019=date1_2019.groupby('BRAND_NAME')['NET_AMT'].sum()
plt.figure(figsize=(21,5))
ax=round(top_1_sal_2019.sort_values(ascending=False)[:20],2).plot(kind='bar')
plt.title("SEP 1st,2019 Top brand vs sales")
plt.xticks(rotation=75)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.02, p.get_height()))
plt.show()

# %%
date1_2019=df_2019.loc[df_2019['date']==1]
top_1_dis_2019=date1_2019.groupby('BRAND_NAME')['MKDN_AMT'].sum()
plt.figure(figsize=(15,5))
ax=round(top_1_dis_2019.sort_values(ascending=False)[:20],2).plot(kind='bar',color='magenta')
plt.title("SEP 1st,2019 Top brand vs discount")
plt.xticks(rotation=75)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.02, p.get_height()))
plt.show()

# %%
top_1_dis_2019.sum()
# Out:
# 1126

# %%
ax=round(date1_2019.groupby('L4_DESC')['MKDN_AMT'].sum(),2)

# %%
ax.sum()
# Out:
# 1126

# %%
date1_2018.MKDN_AMT.sum(),date1_2019.MKDN_AMT.sum()
# Out:
# (1844, 1126)

# %%
date1_2018.NET_AMT.sum(),date1_2019.NET_AMT.sum()
# Out:
# (18347.71, 11718.239999999998)

# %%
date1_2018.shape,date1_2019.shape
# Out:
# ((4886, 24), (3062, 23))

# %%
date1_2018.groupby('STORE_NM')['NET_AMT'].sum()
# Out:
# STORE_NM
# Arese            544.03
# Brembate         812.04
# Busnago         1012.58
# Castelfranco    1111.75
# Cremona         1228.98
# Grandate         712.90
# Lonato           451.83
# Magenta          598.39
# Montebello       891.59
# Monza            691.45
# Orio             811.24
# Portello         757.58
# Rozzano         1040.85
# Rubicone        1357.32
# Seriate         2207.07
# Serravalle       814.71
# Solbiate         464.57
# Tortona          493.70
# Varese           978.91
# Verona           455.42
# Vittuone         910.80
# Name: NET_AMT, dtype: float64

# %%
date1_2019.groupby('STORE_NM')['NET_AMT'].sum()
# Out:
# STORE_NM
# Arese            577.57
# Brembate         516.69
# Busnago          411.26
# Castelfranco     592.35
# Cremona          615.59
# Grandate         385.00
# Lonato           398.67
# Magenta          619.18
# Montebello       520.99
# Monza            300.07
# Orio             370.60
# Portello         681.54
# Rozzano         1048.99
# Rubicone        1038.61
# Seriate          864.42
# Serravalle       580.30
# Solbiate         348.42
# Tortona          357.33
# Varese           864.04
# Verona           270.36
# Vittuone         356.26
# Name: NET_AMT, dtype: float64

# %%
er=date1_2018.groupby('BRAND_NAME')['NET_AMT'].sum()

# %%
er.sort_values(ascending=False)[:20]
# Out:
# BRAND_NAME
# DASH                    2964.17
# SCOTTEX                 1260.19
# FINISH                   996.66
# DIXAN                    982.38
# IPER                     842.19
# SOFFASS REGINA           691.27
# OMINO BIANCO             646.82
# COCCOLINO                567.11
# SVELTO                   561.82
# ACE-FATER                555.83
# CHANTECLAIR              495.84
# PRIL                     392.85
# DELICARTA NICKY          386.54
# VERNEL                   322.02
# WC NET                   320.61
# NAPISAN                  319.97
# VIAKAL                   319.38
# GREY ACCHIAPPACOLORE     317.54
# LENOR                    288.43
# LYSOFORM                 255.52
# Name: NET_AMT, dtype: float64

# %%
er2=date1_2019.groupby('BRAND_NAME')['NET_AMT'].sum()

# %%
er2.sort_values(ascending=False)[:20]
# Out:
# BRAND_NAME
# DASH              2237.77
# IPER               797.26
# FINISH             685.96
# SCOTTEX            578.86
# OMINO BIANCO       495.92
# FOXY               401.00
# DIXAN              327.00
# SVELTO             323.88
# COCCOLINO          292.60
# CHANTECLAIR        289.87
# ACE-FATER          266.19
# WC NET             253.34
# VAPE               250.32
# VERNEL             240.54
# CALGON             221.56
# SOFFASS REGINA     220.44
# NAPISAN            214.62
# LENOR              184.34
# LYSOFORM           182.80
# RAID               175.91
# Name: NET_AMT, dtype: float64

# %%
date1_2019.groupby('STORE_NM')['MKDN_AMT'].sum()
# Out:
# STORE_NM
# Arese            29
# Brembate         37
# Busnago          21
# Castelfranco     93
# Cremona          50
# Grandate         47
# Lonato           22
# Magenta          75
# Montebello       51
# Monza            20
# Orio             17
# Portello         56
# Rozzano         144
# Rubicone         76
# Seriate          66
# Serravalle       57
# Solbiate          4
# Tortona          20
# Varese          160
# Verona           16
# Vittuone         65
# Name: MKDN_AMT, dtype: int64

# %%
df_2018.columns
# Out:
# Index(['TXN_DT', 'HOUSEHOLD_ID', 'STORE_ID', 'UPC_ID', 'NET_AMT', 'ITEM_QTY',
#        'MKDN_AMT', 'FACTS_2019', 'FACTS_2018', 'TRUPRICE_2019',
#        'TRUPRICE_2018', 'UPC_DESC', 'L4 ID', 'L4_DESC', 'L5_ID', 'L5_DESC',
#        'MANUFACTURER_NAME', 'BRAND_NAME', 'STORE_NM', 'REGION_NM', 'year',
#        'date', 'compare_facts', 'price_seg'],
#       dtype='object')

# %%
category_2018=df_2018.groupby(['L4_DESC','L5_DESC'])['NET_AMT'].sum().reset_index(name='count')

# %%
category_2018=category_2018.rename(columns={'L4_DESC':'L4_DESC_2018','L5_DESC':'L5_DESC_2018','count':'count_2018'})

# %%
category_2018
# Out:
#                L4_DESC_2018                   L5_DESC_2018  count_2018
# 0        CARTA IGENICA/CASA                     CARTA CASA    15008.11
# 1        CARTA IGENICA/CASA                 CARTA IGIENICA    29813.64
# 2    CONSERVAZIONE ALIMENTI                     AVVOLGENTI     5846.55
# 3    CONSERVAZIONE ALIMENTI                      SACCHETTI     1822.55
# 4    CONSERVAZIONE ALIMENTI                      VASCHETTE     1753.07
# 5              CURA TESSUTI                       ADDITIVI    12041.17
# 6              CURA TESSUTI                   AMMORBIDENTI    16951.38
# 7              CURA TESSUTI      ANTICALCARE PER LAVATRICE     5440.11
# 8              CURA TESSUTI                     CANDEGGINA     7385.51
# 9              CURA TESSUTI                 PRODOTTI STIRO     1107.64
# 10  DEODORANTI PER AMBIENTE                AZIONE CONTINUA     5945.24
# 11  DEODORANTI PER AMBIENTE              AZIONE ISTANTANEA     1559.04
# ...

# %%
category_2019=df_2019.groupby(['L4_DESC','L5_DESC'])['NET_AMT'].sum().reset_index(name='count')

# %%
overall_l4_l5=pd.concat([category_2018,category_2019],axis=1)

# %%
overall_l4_l5['difference']=overall_l4_l5['count_2018'] - overall_l4_l5['count']

# %%
overall_l4_l5['difference'].sum()
# Out:
# 27120.720000001198

# %%
overall_l4_l5
# Out:
#                L4_DESC_2018                   L5_DESC_2018  count_2018  \
# 0        CARTA IGENICA/CASA                     CARTA CASA    15008.11
# 1        CARTA IGENICA/CASA                 CARTA IGIENICA    29813.64
# 2    CONSERVAZIONE ALIMENTI                     AVVOLGENTI     5846.55
# 3    CONSERVAZIONE ALIMENTI                      SACCHETTI     1822.55
# 4    CONSERVAZIONE ALIMENTI                      VASCHETTE     1753.07
# 5              CURA TESSUTI                       ADDITIVI    12041.17
# 6              CURA TESSUTI                   AMMORBIDENTI    16951.38
# 7              CURA TESSUTI      ANTICALCARE PER LAVATRICE     5440.11
# 8              CURA TESSUTI                     CANDEGGINA     7385.51
# 9              CURA TESSUTI                 PRODOTTI STIRO     1107.64
# 10  DEODORANTI PER AMBIENTE                AZIONE CONTINUA     5945.24
# 11  DEODORANTI PER AMBIENTE              AZIONE ISTANTANEA     1559.04
# ...

# %%
plt.figure(figsize=(15,5))
sns.lineplot(overall_l4_l5.L5_DESC,overall_l4_l5.difference,marker='o',estimator=sum)
plt.title("Difference in sales on sub-category wise b/w 2018 and 2019")
plt.xticks(rotation=75)
plt.show()

# %%
plt.figure(figsize=(15,5))
ax=round(df_2018.groupby('L4_DESC')['NET_AMT'].sum(),2).plot(kind='bar')
plt.xticks(rotation=75)
plt.title("Category vs sales in 2018")
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.001, p.get_height()))
plt.show()

# %%
plt.figure(figsize=(15,5))
ax=round(df_2019.groupby('L4_DESC')['NET_AMT'].sum(),2).plot(kind='bar')
plt.title("Category vs sales in 2019")
plt.xticks(rotation=75)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.001, p.get_height()))
plt.show()

# %%
top_20_2018=round(df_2018.groupby('BRAND_NAME')['NET_AMT'].sum(),2)
plt.figure(figsize=(21,5))
ax=top_20_2018.sort_values(ascending=False)[:20].plot(kind='bar',color='orange')

##df_2018.BRAND_NAME.value_counts()
plt.xticks(rotation=75)
plt.title('Top 20 brands vs sales in 2018')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.001, p.get_height()))

plt.show()

# %%
top_20_2018_dis=round(df_2018.groupby('BRAND_NAME')['MKDN_AMT'].sum(),2)
plt.figure(figsize=(15,5))
ax=top_20_2018_dis.sort_values(ascending=False)[:20].plot(kind='bar')
plt.title("Top 20 brand vs discount in 2018")
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.001, p.get_height()))

plt.show()

# %%
total_diff_brands=

# %%
top_20_2019_dis=round(df_2019.groupby('BRAND_NAME')['MKDN_AMT'].sum(),2)

# %%
plt.figure(figsize=(15,5))
ax=top_20_2019_dis.sort_values(ascending=False)[:20].plot(kind='bar')
plt.title("Top 20 brand vs discount in 2019")
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.001, p.get_height()))

plt.show()

# %%
## Irrespective of high discounts provided in dash the sales are retalively high in 2018 and 2019

# %%
top_20_2019=round(df_2019.groupby('BRAND_NAME')['NET_AMT'].sum(),2)
plt.figure(figsize=(21,5))
ax=top_20_2019.sort_values(ascending=False)[:20].plot(kind='bar',color='orange')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.001, p.get_height()))


##df_2018.BRAND_NAME.value_counts()
plt.xticks(rotation=75)
plt.title('Top 20 brands vs sales in 2019')
plt.show()

# %%
top_20_2019.sort_values(ascending=False)[:20]
# Out:
# BRAND_NAME
# DASH               26911.97
# IPER               22515.13
# FINISH              8811.05
# DIXAN               8747.65
# SCOTTEX             8720.72
# FOXY                6441.19
# CHANTECLAIR         6205.57
# ACE-FATER           5618.11
# OMINO BIANCO        5390.29
# SOFFASS REGINA      4635.79
# WC NET              4340.57
# FAIRY               4250.38
# LENOR               4086.33
# SVELTO              4000.15
# DELICARTA NICKY     3830.17
# COCCOLINO           3554.68
# PRIL                3535.20
# CUKI                3282.71
# CALGON              3208.36
# SOLE                3123.07
# Name: NET_AMT, dtype: float64

# %%
df_2018.

# %%
df_2019.BRAND_NAME.value_counts()[:20]
# Out:
# IPER               13528
# DASH                2672
# ACE-FATER           1945
# CHANTECLAIR         1945
# WC NET              1930
# FINISH              1671
# SCOTTEX             1669
# SVELTO              1542
# FOXY                1505
# CUKI                1467
# OMINO BIANCO        1412
# LENOR               1229
# DELICARTA NICKY     1205
# VERNEL              1200
# SOFFASS REGINA      1066
# LYSOFORM             986
# COCCOLINO            974
# DIXAN                967
# FABULOSO             950
# VALIS                871
# Name: BRAND_NAME, dtype: int64

# %%
df_2018.columns
